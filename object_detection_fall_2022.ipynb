# %% [markdown]
# <p style="align: center;"><img src="https://static.tildacdn.com/tild6636-3531-4239-b465-376364646465/Deep_Learning_School.png", width=500></p>
#
# <h3 style="text-align: center;"><b>Физтех-Школа Прикладной математики и информатики (ФПМИ) МФТИ</b></h3>

# %% [markdown]
# ---

# %% [markdown]
# <h2 style="text-align: center;"><b>Object detection</b></h2>

# %% [markdown]
# ### Руководители проекта:
# * Илья Захаркин (Samsung AI Center - Moscow) | tg:@izakharkin
# * Юрий Яровиков (AIRI, МФТИ) | tg:@yu_rovikov

# %% [markdown]
# <p style="text-align: center;"><img src="https://miro.medium.com/max/750/1*LTPAzUjUentTWoXXmqoT9g.jpeg"></p>

# %% [markdown]
# <h2 style="text-align: center;"><b>Этапы работы</b></h2>

# %% [markdown]
# **1). Выбор фреймворка/библиотеки для использования детектора**
#
# Использовал *torchvision.models.detection*

# %%
import torch
import requests
from PIL import Image
import requests
from io import BytesIO
import IPython

model = torch.hub.load('ultralytics/yolov5', 'yolov5s')  # or yolov5n - yolov5x6, custom

url = 'https://ultralytics.com/images/zidane.jpg'
results = model(url)
print(results.pandas().xyxy[0])
IPython.display.Image(url, width = 250)
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-7-22 Python-3.7.13 torch-1.12.0+cu113 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  742.974792   48.395691  1141.844604  720.000000    0.881052      0  person
# 1  442.007660  437.522400   496.653961  709.973572    0.675214     27     tie
# 2  123.024200  193.287354   715.662231  719.723877    0.665813      0  person
# ...

# %% [markdown]
# **2). Запуск детектора на случайных изображениях**

# %%
url = 'https://kot-pes.com/wp-content/uploads/2019/02/post_5c606e629f934.jpg'
results = model(url)
print(results.pandas().xyxy[0])
IPython.display.Image(url, width = 250)
# Out:
#         xmin       ymin    xmax        ymax  confidence  class name
# 0  63.736145  12.850682  1296.0  877.593384    0.759754     15  cat

# %%
url = 'https://proprikol.ru/wp-content/uploads/2020/02/porodistye-sobaki-krasivye-kartinki-19.jpg'
results = model(url)
print(results.pandas().xyxy[0])
IPython.display.Image(url, width = 250)
# Out:
#          xmin     ymin         xmax    ymax  confidence  class name
# 0  146.014359  63.1506  1128.360718  1538.0     0.70158     16  dog

# %%
url = 'https://w-dog.ru/wallpapers/2/1/547308366673993/malenkaya-obezyanka-izuchaet-mir.jpg'
results = model(url)
print(results.pandas().xyxy[0])
IPython.display.Image(url, width = 250)
# Out:
#         xmin       ymin         xmax         ymax  confidence  class name
# 0  45.887054  14.789062  1347.251587  1176.499146    0.642443     16  dog

# %% [markdown]
# <h3 style="text-align: center;"><b>1 сценарий</b></h3>

# %% [markdown]
# **3). Выбор фреймворка/библиотеки для разработки веб/мобильного демо**

# %% [markdown]
# > В качестве backend фреймворка будет использоваться FastAPI, frontend: Nuxt, UX UI vuetify.
#
# ---
# Все это будет собрано в Docker с использованием docker-compose

# %% [markdown]
# **4). Разработка демо**

# %% [markdown]
# > Можно отследить по commit в репозитории

# %% [markdown]
# **5). Встраивание модели-детектора в демо**

# %% [markdown]
# Помимо YoloV5 модели, будут использоваться ряд других моделей (посмотреть их можно по пути app/model.py)
#
# frcnn-resnet
#
# frcnn-mobilenet
#
# retinanet

# %% [markdown]
# **6). Тестирование демо**

# %% [markdown]
# [Открыть демо](http://deeplearning.steepman.pw/)
#
# <p style="align: center;"><img src="https://i.imgur.com/h5iYn39.png", width=500></p>
#
# <p style="align: center;"><img src="https://i.imgur.com/P0PEyXf.png", width=500></p>
#
# <p style="align: center;"><img src="https://i.imgur.com/q6WeOOU.png", width=500></p>

# %% [markdown]
# **7). Оформление демо для показа другим людям**

# %% [markdown]
# Для выпуска демо в общий доступ, использовалось VDS
